# %%
from meteostat import Stations

stations = Stations()
stations = stations.region('US', 'ID')

stations._data
# Out:
#                                                name country region    wmo  \
# id
# 72578                    Pocatello Regional Airport      US     ID  72578
# 72586                              Gooding / Fuller      US     ID  72586
# 72681                            Boise Air Terminal      US     ID  72681
# 72686                                Salmon / Baker      US     ID  72686
# 72783                 Lewiston Nez Perce Co Airport      US     ID  72783
# K65S0              Bonners Ferry / Threemile Corner      US     ID   <NA>
# KBYI0                              Burley / Heyburn      US     ID   <NA>
# KCOE0                        Coeur D'alene / Hayden      US     ID   <NA>
# KDIJ0                                        Driggs      US     ID   <NA>
# KEUL0                             Caldwell / Midway      US     ID   <NA>
# KGIC0                                   Grangeville      US     ID   <NA>
# KIDA0                           Idaho Falls / Orvin      US     ID   <NA>
# ...

# %%
from datetime import datetime, timedelta
from meteostat import Hourly, Point

data = Hourly(
    '72681',
    datetime(2020, 1, 1), 
    datetime(2020, 1, 1)
).fetch()

# %%
data.iloc[0].wspd * 0.277
# Out:
# 20.5

# %%
import numpy as np

# %%
np.log(100/0.0001)
# Out:
# 13.815510557964274

# %%
14%14
# Out:
# 0

# %%
for i in range(10):
    print( (20+20*0.277)*np.log((20)/30)*1*1 )
# Out:
# -10.35557886108252
# -10.35557886108252
# -10.35557886108252
# -10.35557886108252
# -10.35557886108252
# -10.35557886108252
# -10.35557886108252
# -10.35557886108252
# -10.35557886108252
# -10.35557886108252

# %%
np.log(0.001)
# Out:
# -6.907755278982137
